# %% [markdown]
# <a href="https://colab.research.google.com/github/hyperpipe-kr/colab-examples/blob/main/05_CNN_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EB%B6%84%EB%A5%98_%EB%AA%A8%EB%8D%B8_%EA%B0%9C%EC%84%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 기반 이미지 분류

# %% [markdown]
# `tf.keras.Sequential` 모델을 사용하여 꽃 이미지를 분류하고 `tf.keras.utils.image_dataset_from_directory`를 사용하여 데이터를 로드하는 방법을 보여줍니다.

# %% [markdown]
# ## 설정
#
# TensorFlow 및 기타 필요한 라이브러리를 가져옵니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## 데이터세트 다운로드 및 탐색하기

# %% [markdown]
# 아래 파일을 다운로드합니다.
# https://drive.google.com/file/d/1CetAhdag_67V9mjAiB2l7ldufS8OX5oA/view?usp=sharing
# 압축을 풀고 약 3,700장의 꽃 사진 데이터세트를 사용합니다. 데이터세트에는 클래스당 하나씩 5개의 하위 디렉터리가 있습니다.
#
# ```
# flower_photo/
#   daisy/
#   dandelion/
#   roses/
#   sunflowers/
#   tulips/
# ```

# %% [markdown]
# 구글 드라이브에 연동하고 /content/drive/MyDrive/lg-dx/ 경로에 업로드합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pathlib
data_dir = "/content/drive/MyDrive/lg-dx/flower_photos"
data_dir = pathlib.Path(data_dir).with_suffix('')

# %% [markdown]
# 업로드된 폴더를 불러와서 데이터세트 사본을 사용할 수 있습니다. 총 3,670개의 이미지가 있습니다.

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %% [markdown]
# 장미의 경우는 다음과 같습니다.

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %% [markdown]
# 그리고 일부 튤립이 있습니다.

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213>

# %%
PIL.Image.open(str(tulips[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=145x240>

# %% [markdown]
# ## Keras 유틸리티를 사용하여 데이터 로드하기
#
# 다음으로, 유용한 `tf.keras.utils.image_dataset_from_directory` 유틸리티를 사용하여 디스크에서 이러한 이미지를 로드해 보겠습니다. 이러면 몇 줄의 코드로 디스크의 이미지 디렉터리에서 `tf.data.Dataset`로 이동하게 됩니다.

# %% [markdown]
# ### 데이터세트 만들기

# %% [markdown]
# 로더에 대한 몇 가지 매개변수를 정의합니다.

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# 모델을 개발할 때 검증 분할을 사용하는 것이 좋습니다. 이미지의 80%를 훈련에 사용하고 20%를 검증에 사용합니다.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %% [markdown]
# 이러한 데이터세트의 `class_names` 속성에서 클래스 이름을 찾을 수 있습니다. 이들 클래스 이름은 알파벳 순서의 디렉토리 이름에 해당합니다.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %% [markdown]
# ## 데이터 시각화하기
#
# 다음은 훈련 데이터세트의 처음 9개 이미지입니다.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# 이 튜토리얼의 뒷부분에서 훈련을 위해 이러한 데이터세트를 `Model.fit` 메서드에 전달합니다. 원하는 경우 데이터세트를 수동으로 반복하고 이미지 배치를 가져올 수도 있습니다.

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# `image_batch`는 `(32, 180, 180, 3)` 형상의 텐서이며, `180x180x3` 형상의 32개 이미지 묶음으로 되어 있습니다(마지막 차원은 색상 채널 RGB를 나타냄). `label_batch`는 형상 `(32,)`의 텐서이며 32개 이미지에 해당하는 레이블입니다.
#
# `image_batch` 및 `labels_batch` 텐서에서 `.numpy()`를 호출하여 이를 `numpy.ndarray`로 변환할 수 있습니다.

# %% [markdown]
# ## 성능을 높이도록 데이터세트 구성하기
#
# 버퍼링된 프리페치를 사용하여 I/O를 차단하지 않고 디스크에서 데이터를 생성할 수 있도록 하겠습니다. 데이터를 로드할 때 다음 두 가지 중요한 메서드를 사용해야 합니다.
#
# - `Dataset.cache()`는 첫 epoch 동안 디스크에서 이미지를 로드한 후 이미지를 메모리에 유지합니다. 이렇게 하면 모델을 훈련하는 동안 데이터세트가 병목 상태가 되지 않습니다. 데이터세트가 너무 커서 메모리에 맞지 않는 경우, 이 메서드를 사용하여 성능이 높은 온디스크 캐시를 생성할 수도 있습니다.
# - `Dataset.prefetch`는 훈련하는 동안 데이터 전처리 및 모델 실행을 중첩시킵니다.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 데이터 표준화하기

# %% [markdown]
# RGB 채널 값은 `[0, 255]` 범위에 있습니다. 이것은 신경망에 이상적이지 않습니다. 일반적으로 입력 값을 작게 만들어야 합니다.
#
# 여기에서 `tf.keras.layers.Rescaling`을 사용하여 값을 `[0, 1]` 범위로 표준화합니다.

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# 참고: 이전에 `tf.keras.utils.image_dataset_from_directory`의 `image_size` 인수를 사용하여 이미지 크기를 조정했습니다. 해당 모델에도 크기 조정 논리를 포함하려면 `tf.keras.layers.Resizing` 레이어를 사용할 수 있습니다.

# %% [markdown]
# ## 기본 Keras 모델
#
# ### 모델 만들기
#
# Keras [순차형](https://www.tensorflow.org/guide/keras/sequential_model) 모델은 각각에 최대 풀링 레이어(`tf.keras.layers.MaxPooling2D`)가 있는 1개의 컨볼루션 블록(`tf.keras.layers.Conv2D`)으로 구성됩니다. ReLU 활성화 함수(`'relu'`)에 의해 활성화되는 128개 유닛이 있는 완전 연결된 레이어(`tf.keras.layers.Dense`)가 있습니다.

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# - layers.Rescaling(1./255, input_shape=(img_height, img_width, 3))
# 입력 이미지의 픽셀 값을 0-1 범위로 바꿔주는 전처리 층입니다. 보통 이미지 픽셀은 0-255 사이 정수인데, 여기에 1/255를 곱해 0-1로 정규화합니다. 신경망은 입력값이 작고 균일한 범위에 있을 때 학습이 안정적이라 이 과정을 넣습니다. input_shape=(img_height, img_width, 3)은 이 모델이 받는 입력 형태를 알려주는데, 세로·가로 픽셀 수에 채널 3개(RGB 컬러)라는 뜻입니다. 이 층이 모델의 첫 층이라 여기서 입력 모양을 명시합니다.
#
# - layers.Conv2D(16, 3, padding='same', activation='relu')
# 이미지의 특징을 뽑아내는 합성곱 층입니다. 핵심 역할을 하는 층이죠. 숫자의 의미는:
# 16 — 필터(filter) 16개를 사용합니다. 각 필터는 이미지에서 서로 다른 패턴(가장자리, 곡선, 색 변화 등)을 찾는 작은 탐지기라고 보면 됩니다. 결과적으로 16장의 특징 맵(feature map)이 나옵니다.
# 3 — 필터 크기가 3×3이라는 뜻입니다. 이미지를 3×3 창으로 훑으며 지역적인 패턴을 봅니다.
# padding='same' — 이미지 가장자리에 여백(0)을 채워, 출력의 가로·세로 크기를 입력과 같게 유지합니다. 이게 없으면 합성곱을 거칠 때마다 이미지가 조금씩 작아집니다.
# activation='relu' — 활성화 함수로 ReLU를 씁니다. 음수는 0으로 만들고 양수는 그대로 두는 함수인데, 모델이 단순한 직선 관계를 넘어 복잡한 패턴을 학습할 수 있게 해주는 비선형성을 넣어줍니다.
#
# - layers.MaxPooling2D()
# 특징 맵의 크기를 절반으로 줄이는 층입니다. 기본값으로 2×2 영역을 보고 그중 가장 큰 값 하나만 남깁니다. 이렇게 하면 세로·가로가 각각 절반이 되죠. 이점은 두 가지입니다: 계산할 데이터 양이 줄어 가벼워지고, 위치가 조금 달라져도 같은 특징으로 인식하게 되어(위치에 덜 민감해짐) 더 튼튼한 모델이 됩니다. 중요한 특징(강한 신호)만 추려낸다고 생각하면 됩니다.
#
# - layers.Flatten()
# 지금까지는 데이터가 "가로 × 세로 × 채널"의 3차원 격자 형태였습니다. 그런데 다음에 올 Dense 층은 1차원으로 쭉 늘어선 값만 받을 수 있어서, 이 격자를 한 줄로 펴주는 층입니다. 예를 들어 (높이, 너비, 16) 형태를 그냥 긴 벡터 하나로 이어붙입니다. 값 자체는 그대로고 모양만 바꿉니다.
# layers.Dense(128, activation='relu')
# 완전 연결(fully connected) 층으로, 뉴런 128개를 가집니다. 앞에서 뽑아낸 특징들을 조합해 "이 특징들이 모이면 어떤 의미인지"를 학습하는 부분입니다. 여기서도 ReLU를 써서 비선형적인 조합을 배울 수 있게 합니다.
#
# - layers.Dense(num_classes)
# 마지막 출력 층입니다. 뉴런 수가 num_classes, 즉 분류하려는 클래스 개수와 같습니다(꽃 5종류라면 5). 각 뉴런이 해당 클래스에 대한 점수를 하나씩 내놓습니다. 여기서는 활성화 함수를 지정하지 않았으므로 출력은 로짓(logit, raw 점수) 입니다. 앞선 예제들에서 봤던 것처럼, softmax를 마지막에 붙이지 않고 로짓을 그대로 두는 이유는 손실 계산이 수치적으로 더 안정적이기 때문입니다. 실제로 확률이 필요할 때 softmax를 따로 적용하면 됩니다.
#
# 전체 흐름을 한 문장으로
# 컬러 이미지가 들어오면 → 픽셀을 0~1로 정규화하고 → 합성곱으로 특징을 뽑고 → 풀링으로 요약·축소하고 → 한 줄로 펴서 → Dense 층으로 특징을 조합한 뒤 → 클래스별 점수를 출력하는, 이미지 분류 CNN의 가장 기본적이고 전형적인 구조입니다.

# %% [markdown]
# ### 모델 컴파일하기
#
# 이 튜토리얼에서는 `tf.keras.optimizers.Adam` 옵티마이저와 `tf.keras.losses.SparseCategoricalCrossentropy` 손실 함수를 선택합니다. 각 훈련 epoch에 대한 훈련 및 검증 정확도를 보려면 `metrics` 인수를 `Model.compile`에 전달합니다.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### 모델 요약
#
# Keras `Model.summary` 메서드를 사용하여 네트워크의 모든 레이어를 봅니다.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 129600)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │    16,588,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,590,021 (63.29 MB)
#  Trainable params: 16,590,021 (63.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 모델 훈련하기

# %% [markdown]
# Keras `Model.fit` 메서드를 사용하여 5 epoch 동안 모델을 훈련합니다.

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  verbose=1
)
# Out:
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 371s 882ms/step - accuracy: 0.4401 - loss: 3.1421 - val_accuracy: 0.5450 - val_loss: 1.1381
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6342 - loss: 0.9673 - val_accuracy: 0.6049 - val_loss: 1.0541
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7568 - loss: 0.6938 - val_accuracy: 0.5708 - val_loss: 1.0726
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8501 - loss: 0.4790 - val_accuracy: 0.5967 - val_loss: 1.0742
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9237 - loss: 0.2965 - val_accuracy: 0.6104 - val_loss: 1.1195
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9622 - loss: 0.1713 - val_accuracy: 0.6131 - val_loss: 1.2297
# Epoch 7/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9843 - loss: 0.0989 - val_accuracy: 0.6172 - val_loss: 1.2009
# Epoch 8/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9942 - loss: 0.0569 - val_accuracy: 0.6076 - val_loss: 1.2653
# Epoch 9/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9956 - loss: 0.0414 - val_accuracy: 0.5708 - val_loss: 1.4934
# Epoch 10/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9969 - loss: 0.0299 - val_accuracy: 0.6022 - val_loss: 1.5931

# %% [markdown]
# ## 훈련 결과 시각화하기

# %% [markdown]
# 훈련 및 검증 세트에 대한 손실과 정확성 플롯을 생성합니다.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## 과대적합

# %% [markdown]
# 위의 플롯에서 훈련 정확성은 시간이 지남에 따라 선형적으로 증가하는 반면, 검증 정확성은 훈련 과정에서 약 60%를 벗어나지 못합니다. 또한 훈련 정확성과 검증 정확성 간의 정확성 차이가 상당한데, 이는 [과대적합](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit)의 징후입니다.
#
# 훈련 예제가 적을 때 모델은 새로운 예제에서 모델의 성능에 부정적인 영향을 미치는 정도까지 훈련 예제의 노이즈나 원치 않는 세부까지 학습합니다. 이 현상을 과대적합이라고 합니다. 이는 모델이 새 데이터세트에서 일반화하는 데 어려움이 있음을 의미합니다.
