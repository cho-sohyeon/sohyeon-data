# %%
import pandas as pd

# %%
df = pd.read_csv("./Data/yes24/yes24_ai.csv")
df
# Out:
#                                             제목                             저자  \
# 0                      요즘 바이브 코딩 클로드 코드 완벽 가이드                            최지호
# 1                       AI 시대의 질문력, 프롬프트 엔지니어링                            류한석
# 2     요즘 교사를 위한 AI 수업 활용 가이드 with 2022 개정 교육과정                  박진환, 공지훈, 서원진
# 3                           밑바닥부터 만들면서 배우는 LLM                세바스찬 라시카 /박해선 역
# 4                             AI 시대의 필수 문해력 수업                            조기준
# ...                                        ...                            ...
# 1195                       챗GPT 슬기로운 일상생활의 자동화                  주방현, 윤명희, 이동호
# 1196                            블록체인과 인공지능의 융합                            한승무
# 1197                 한번에 끝내는 빅데이터 분석 및 인공지능 기초                            정은미
# 1198                   텐서플로와 케라스로 구현하는 딥러닝 3/e  아미타 카푸어, 안토니오 걸리, 수짓 팔 /이병욱 역
# 1199                                핸즈온 비지도 학습          안쿠르 A. 파텔 /강재원, 권재철 역
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   제목          1200 non-null   str
#  1   저자          1200 non-null   str
#  2   출판사         1200 non-null   str
#  3   발행일         1199 non-null   str
#  4   정가          1198 non-null   float64
#  5   판매가         1200 non-null   int64
#  6   리뷰 수        1200 non-null   int64
#  7   판매지수        1200 non-null   str
#  8   상세 정보       0 non-null      float64
#  9   설명          1175 non-null   str
#  10  상세 페이지 URL  1200 non-null   str
# dtypes: float64(2), int64(2), str(7)
# memory usage: 103.3 KB
