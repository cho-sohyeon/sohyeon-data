# %% [markdown]
# 데이터 프레임 만들기

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.2'

# %%
data = {
    '이름': ['김철수', '이영희', '박민수', '최지우'],
    '영어': [90, 85, 88, 95],
    '수학': [82, 92, 78, 88]
}

# %%
df = pd.DataFrame(data) 
df
# Out:
#     이름  영어  수학
# 0  김철수  90  82
# 1  이영희  85  92
# 2  박민수  88  78
# 3  최지우  95  88

# %%
tmp = df["영어"]
tmp
# Out:
# 0    90
# 1    85
# 2    88
# 3    95
# Name: 영어, dtype: int64

# %%
type(tmp), type(df)
# Out:
# (pandas.Series, pandas.DataFrame)

# %%
import site 
print(site.getsitepackages)
# Out:
# <function getsitepackages at 0x000001C2E9686820>

# %%
for jum in data["영어"]:
    print(jum)
# Out:
# 90
# 85
# 88
# 95

# %%
df["영어"].sum()
# Out:
# np.int64(358)

# %%
df["영어"].max(), df["영어"].min()
# Out:
# (np.int64(95), np.int64(85))

# %%
sum(df["수학"])
# Out:
# 340

# %% [markdown]
# 외부 데이터 읽어오기

# %%
# !uv pip install openpyxl
# Out:
# Checked 1 package in 21ms

# %%
df_exam_novar = pd.read_excel("./Data/excel_exam_novar.xlsx")
df_exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
df_exam = pd.read_excel("./Data/excel_exam.xlsx")
df_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# csv 파일 읽어 오기

# %%
df_csv_exam = pd.read_csv("./Data/exam.csv")
df_csv_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# 값 변수, 참조 변수

# %%
a = 1 
b = a 
a =3 
print(a, b)
# Out:
# 3 1

# %%
c = [ 1, 2, 3]
d = c
c[1] = 5 
print(c, d)
# Out:
# [1, 5, 3] [1, 5, 3]

# %% [markdown]
# 데이터 프레임 저장하기

# %%
temp = df_csv_exam[["math", "english"]]

# %%
temp.to_csv("./output_new_data.csv")

# %%
output_new_data = pd.read_csv("output_new_data.csv")
output_new_data
# Out:
#     Unnamed: 0  math  english
# 0            0    50       98
# 1            1    60       97
# 2            2    45       86
# 3            3    30       98
# 4            4    25       80
# 5            5    50       89
# 6            6    80       90
# 7            7    90       78
# 8            8    20       98
# 9            9    50       98
# 10          10    65       65
# 11          11    45       85
# 12          12    46       98
# 13          13    48       87
# 14          14    75       56
# 15          15    58       98
# 16          16    65       68
# 17          17    80       78
# 18          18    89       68
# 19          19    78       83

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df["수학"].plot.bar()
# Out:
# <Axes: >
