# %% [markdown]
# # 인터랙티브 그래브

# %%
# !uv pip install plotly
# Out:
# Checked 1 package in 3ms

# %%
import pandas as pd

# %%
import plotly.express as px

# %%
# !uv pip install seaborn
# Out:
# Checked 1 package in 5ms

# %%
import seaborn as sns

# %%
pd.read_csv('https://raw.githubusercontent.com/youngwoos/Doit_Python/main/Data/mpg.csv')
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
px.scatter(data_frame=mpg, x = 'cty', y= 'hwy', color = 'drv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 px.scatter(data_frame=mpg, x = 'cty', y= 'hwy', color = 'drv')
#
# NameError: name 'mpg' is not defined

# %%
df = mpg.groupby('category', as_index=False).agg(n = ('category', 'count'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = mpg.groupby('category', as_index=False).aff(n = ('category', 'count'))
#
# NameError: name 'mpg' is not defined

# %%
px.bar(data_frame=df, x = 'category', y = 'n', color = 'category')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 px.bar(data_frame=df, x = 'category', y = 'n', color = 'category')
#
# NameError: name 'df' is not defined
