# %% [markdown]
# BX 6기 1반 답안지입니다.
# * 한 셀에 한 문제씩 답안만 작성해주세요.

# %% [markdown]
# ## 파이썬 기초문법

# %% [markdown]
# ### 1~7번: 이론 문제 (총 14점)

# %%
# Q1
+, -

# %%
# Q2
True, False

# %%
# Q3
append, insert

# %%
# Q4
def

# %%
# Q5
딕셔너리 : 중괄호 
리스트 : 대괄호

# %%
# Q6
클래스 : 객체를 만들기 위한 틀 
객체 : 클래스를 통해 만들어진 인스턴스

# %%
# Q7
3,4

# %% [markdown]
# ### 8~10번: 실습 문제 (총 11점)

# %%
# Q8

texts = ["원숭이 엉덩이는 빨개~", "빨가면 사과", "사과는 맛있어",
"맛있으면 바나나", "바나나는 길어", "길면 기차",
"기차는 빨라", "빠르면 비행기", "비행기는 높아", "높으면 백두산!"]

for text in texts: 
    print(text)

# %%
# Q9
def check_number():
    return 

check_number(5)
check_number(-3)
check_number(0)

# %%
# Q10

class Student: 
    def __init__(self, name, age): 
        self.name = name 
        self.age = age 

    def.introduce(self):
        print(f"안녕하세요, 저는 {name}이고, {age}살입니다.") 

student1 = Student("나영", 17)
student1.introduce()

# %% [markdown]
# ## 파이썬 라이브러리(데이터분석)

# %% [markdown]
# ### 1~6번: 이론 문제 (총 13점)

# %%
# Q1
1

# %%
# Q2
2

# %%
# Q3
2

# %%
# Q4
1

# %%
# Q5
1

# %%
# Q6
score.describe()

# %% [markdown]
# ### 7~10번: 실습 문제 (총 12점)

# %%
# Q7
cafe_sales = pd.read_csv('cafe_sales.csv')

# %%
# Q8
df[''].sum()

# %%
# Q9
df[] = df[].fillna(0) 
df

# %%
# Q10
import pandas as pd

df = pd.DataFrame({
'name': ['A', 'B', 'C', 'D'],
'score': [70, 85, 90, 60]
})

score >= 80 
print(score)

# %% [markdown]
# ## 데이터베이스
# * 실습은 SQL DEVELOPER를 열어 LG_DB계정에서 진행하시면 됩니다

# %% [markdown]
# ### 1~2번: 이론 문제 (총 4점)

# %%
# Q1
데이터 수집 - 데이터 분석 - 데이터 시각화

# %%
# Q2
관계차수: 관계의 참여도, 엔터티 내 인스턴스가 관계에 얼마나 참여하는지 기술 
관계선택성: 엔터티 내 인스턴스가 관계에 꼭 차명해야 하는지 기술 
관계명: 무슨 관계를 가지고 있는지 동사형, 현재진행형으로 기술

# %% [markdown]
# ### 3~9번: 실습 문제 (총 21점)

# %%
# Q3
SELECT NAME
     , RETIRE_YN
     , GENDER
    , JOB_TITLE 
    FROM EMP
 WHERE RETIRE_YN = 'N'AND GENDER = '남성' AND JOB_TITLE = '팀장'
ORDER BY NAME DESC ;

# %%
# Q4
SELECT PRODUCT_ID 
     , REVIEW COUNT(*) AS 리뷰5점계수 
  FROM PRODUCT_REVIEW 
ORDER BY PRODUCT_ID DESC
WHERE REVIEW = 5 ;

# %%
# Q5
CREATE TABLE MEMBER_EXAM (
    MEMBER_ID VARCHAR2(20)PRIMARY KEY(MEMBER_ID)
    NAME VARCHAR2(50), NOT NULL
    ID_NUMBER VARCHAR2(255)PRIMARY KEY(ID_NUMBER)
    JOIN_DATE DATE DEFAULT SYSDATE
);

# %%
# Q6
SELECT A.DEPT_NAME 
    ,A.DEPT_NO 
    ,B.DEPT_NAME 
    ,B.DEPT_NO
  FROM DEPT A INNER JOIN EMP B 
ORDER BY DEPT_NAME DESC
    ON A.DEPT_NAME = B.DEPT_NAME ;

# %%
# Q7
CREATE TABLE MEMBER_EXAM (
    MEMBER_ID VARCHAR2(20)PRIMARY KEY
    NAME VARCHAR2(50), NOT NULL
    ID_NUMBER VARCHAR2(255)PRIMARY KEY
    JOIN_DATE DATE DEFAULT SYSDATE
);

# %%
# Q8
INSERT INTO MEMBER_ID VALUES 'AAA';
INSERT INTO NAME VALUES '짱구' ;
INSERT INTO ID_NUMBER VALUES '001212-1234567' ;
INSERT INTO JOIN_DATE VALUES SYSDATE ;

# %%
# Q9
ALTER TABLE MEMBER_EXAM RENAME COLNUM MEMBER_ID TO '맹구' ;

# %% [markdown]
# ## 웹크롤링

# %% [markdown]
# ### 1~4번: 이론 문제 (총 8점)

# %%
# Q1
크롤링은 자동화된 방법으로 다양한 정보를 수집하는 소프트웨어를 의미하며, 
범용성이 큰 동적데이터를 수집할 수 있다.

# %%
# Q2
http 메시지의 진행상태에 따른 성공 상태

# %%
# Q3
Selenium : 정적 데이터만 수집 가능 
BeautifulSoup : 동적인 데이터만 수집 가능

# %%
# Q4
1번은 요소를 한개만 가지고 올 수 있고, 2번은 요소를 2개이상 가지고 올 수 있음

# %% [markdown]
# ### 5번: 실습 문제 (총 17점)

# %%
# Q5

from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time 
pre_source = driver.page_source
body = driver.find_element(By.CSS_SELECTOR, 'body') 

product_list = [] 
model_list = [] 
rating_list = [] 

while True: 
    driver.get('https://www.lge.co.kr/home-audio') 
    time.sleep(1)

    product = driver.find_elements(By.XPATH, '//*[@id="container"]/section[7]/section[2]/section[2]/ul/li[1]/div[5]/a/div/p/strong')
    product.append([i text for i in product]) 

    model = driver.find_elements(By.XPATH, '//*[@id="container"]/section[7]/section[2]/section[2]/ul/li[1]/div[5]/div[2]/div/span[1]') 
    model.append([i text for i in model]) 

    rating = driver.find_elemets(By.XPATH, '//*[@id="container"]/section[7]/section[2]/section[2]/ul/li[1]/div[5]/div[2]/div/span[2]/span[2]') 
    raitng.append([i text for i in rating]) 


    
import pandas as pd 

data = { '상품명' : product_list. '모델명' : model_list, '평점' : rating_list} 
df = pd.DataFrame(data) 
df 

df.to_csv('LG전자.csv')
